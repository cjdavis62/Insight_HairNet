# %%
import instaloader

# %%
USER="cjdavis_physics"

# %%
L = instaloader.Instaloader()
L.interactive_login(USER)
# Out:
# Enter Instagram password for cjdavis_physics:  ··········

# %%
for post in L.get_hashtag_posts('salonblonde'):
    L.download_post(post, target='salonblonde')
# Out:
# salonblonde/2019-06-09_03-40-26_UTC_1.jpg salonblonde/2019-06-09_03-40-26_UTC_2.jpg salonblonde/2019-06-09_03-40-26_UTC_3.jpg salonblonde/2019-06-09_03-40-26_UTC_4.jpg [Us to hard working hotties le…] geo json
# salonblonde/2019-06-08_12-27-50_UTC.jpg [▫️r e e s e▫️] geo comments json
# salonblonde/2019-06-07_23-32-01_UTC.jpg [She blonde! 🙌🏻🙌🏻 Thanks @call…] comments json
# salonblonde/2019-06-07_07-16-58_UTC_1.jpg salonblonde/2019-06-07_07-16-58_UTC_2.jpg [💥CHECK OUT THE BEFORE PIC ON …] geo comments json
# salonblonde/2019-06-06_20-08-34_UTC.jpg [Love 💜 this beautiful Red and…] geo comments json
# salonblonde/2019-06-06_18-50-28_UTC.jpg [▫️k i m m y▫️] salonblonde/2019-06-06_18-50-28_UTC.mp4 geo comments json
# salonblonde/2019-06-06_18-41-33_UTC_1.jpg salonblonde/2019-06-06_18-41-33_UTC_2.jpg [😍😍 . . . #springhilltn #colum…] geo json
# salonblonde/2019-06-06_10-57-37_UTC.jpg [💖 Perfectly P I N K 💖  How go…] geo comments json
# ...
